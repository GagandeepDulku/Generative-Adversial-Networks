# %% [markdown]
# ### This code is to test the ouptut of the trained generator

# %%
import tensorflow as  tf
import os
from helper import *

# Params
grid_size = 5                                            # Size of the grid
save_img_flag = True                                     # Flag to save the grid plot as png image file
img_path = "Generated Image Grid_"+str(grid_size)+".png" # image file name
model_path = "models"                                    # local directory containing generator model's .h5 file


# Load generator model
gen_model = tf.keras.models.load_model(os.path.join(model_path, "generator_model.h5"))

# Plot/save the grid of generated images
plot_gen_images(gen_model,                               # Generator model (tensorflow sequential)
                grid_size,                               # Size of the grid
                save_img_flag,                           # Flag to save the grid plot as png image file
                os.path.join("generated_img", img_path)) # image file name
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
